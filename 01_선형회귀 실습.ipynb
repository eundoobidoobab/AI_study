# %% [markdown]
# # 최소제곱법 실습

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# x값과 y값
x = [2, 4, 6, 8]
y = [81, 93, 91, 97]

# x와 y의 평균값
mx = np.mean(x)
my = np.mean(y)
print("x의 평균값:", mx)
print("y의 평균값:", my)

#기울기 공식의 분모
divisor = sum([(mx - i)**2 for i in x])
# Out:
# x의 평균값: 5.0
# y의 평균값: 90.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def top(x, mx, y, my):
    d = 0
    for i in range(len(x)):
        d += (x[i] - mx) * (y[i] - my)
    return d
dividend = top(x, mx, y, my)

print("분모:", divisor)
print("분자:", dividend)

a = dividend / divisor
b = my - (mx*a)

print("기울기 a=", a)
print("y 절편 b=", b)
# Out:
# 분모: 20.0
# 분자: 46.0
# 기울기 a= 2.3
# y 절편 b= 79.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# x값과 y값
x = [1, 2, 3, 4, 5, 6, 7, 8] #주
y = [0.2, 0.3, 0.5, 0.6, 0.9, 0.95, 1.1, 1.5] #크기
maxSize = 30

# x와 y의 평균값
mx = np.mean(x)
my = np.mean(y)
print("x의 평균값:", mx)
print("y의 평균값:", my)

#기울기 공식의 분모
divisor = sum([(mx - i)**2 for i in x])

# 기울기 공식의 분자
def top(x, mx, y, my):
    d = 0
    for i in range(len(x)):
        d += (x[i] - mx) * (y[i] - my)
    return d
dividend = top(x, mx, y, my)

#기울기와 y절편 구하기
a = dividend / divisor
b = my - (mx*a)

print("분모:", divisor)
print("분자:", dividend)
print("기울기 a=", a)
print("y 절편 b=", b)

def sizeOf(x):
    global maxSize
    v = a * x + b
    if v < maxSize:
        v = round(v, 3) #물고기 크기는 최대 30cm로 가정
    else:
        v = maxSize
    return v

print("15주 후의 크기 :", sizeOf(15), "cm")
print("25주 후의 크기 :", sizeOf(25), "cm")
print("77주 후의 크기 :", sizeOf(77), "cm")
print("200주 후의 크기 :", sizeOf(200), "cm")
print("5주차 예상치와 차이:", 
      round(0.9 - sizeOf(5), 3), "cm")
# Out:
# x의 평균값: 4.5
# y의 평균값: 0.7562500000000001
# 분모: 42.0
# 분자: 7.375
# 기울기 a= 0.17559523809523808
# y 절편 b= -0.03392857142857131
# 15주 후의 크기 : 2.6 cm
# 25주 후의 크기 : 4.356 cm
# 77주 후의 크기 : 13.487 cm
# 200주 후의 크기 : 30 cm
# 5주차 예상치와 차이: 0.056 cm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 평균 제곱근 오차

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

ab = [3, 76]

data = [[2, 81], [4, 93], [6, 91], [8, 97]]
x = [i[0] for i in data]
y = [i[1] for i in data]

def predict(x):
    return ab[0] * x + ab[1]

# %%
# RMSE 함수
def rmse(p, a):
    return np.sqrt(((p - a) ** 2).mean())

def rmse_val(predict_result, y):
    return rmse(np.array(predict_result), np.array(y))

predict_result = []

for i in range(len(x)):
    predict_result.append(predict(x[i]))
    print("공부한 시간 - %.f, 실제 점수 = %.f, 예측 점수 = %.f" % (x[i], y[i], predict(x[i])))
# Out:
# 공부한 시간 - 2, 실제 점수 = 81, 예측 점수 = 82
# 공부한 시간 - 4, 실제 점수 = 93, 예측 점수 = 88
# 공부한 시간 - 6, 실제 점수 = 91, 예측 점수 = 94
# 공부한 시간 - 8, 실제 점수 = 97, 예측 점수 = 100

# %%
print(predict_result)
print(y)
# Out:
# [82, 88, 94, 100]
# [81, 93, 91, 97]

# %%
print("rmse 최종값: ", str(rmse_val(predict_result, y)))
# Out:
# rmse 최종값:  3.3166247903554
